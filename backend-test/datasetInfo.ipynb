# %%
import pandas as pd

# %%
df = pd.read_csv("plant_dataset_100k.csv")
df.columns
# Out:
# Index(['id', 'common_name', 'scientific_name', 'category',
#        'oxygen_output_g_per_day', 'suitable_season', 'soil_type',
#        'region_preference', 'uses', 'sunlight_requirement',
#        'watering_frequency', 'fertilizer_type', 'indoor_outdoor',
#        'recommended_area_sqm', 'growth_rate', 'pruning_frequency',
#        'harvesting_timeline', 'common_diseases', 'care_instructions',
#        'image_url', 'description'],
#       dtype='object')

# %%
df["category"].value_counts()
# Out:
# category
# ['indoor']                                    65
# Herb                                          65
# ['medicinal']                                 61
# ['succulent']                                 60
# Medicinal                                     60
#                                               ..
# ['air purifying', 'medicinal', 'herb']         1
# ['herb', 'succulent', 'outdoor']               1
# ['ornamental', 'outdoor', 'air purifying']     1
# ['medicinal', 'herb', 'indoor']                1
# ['outdoor', 'air purifying', 'flowering']      1
# Name: count, Length: 279, dtype: int64

# %%
df["region_preference"].unique()
# Out:
# array(['West India', 'Mediterranean', 'South India', 'North India',
#        'Central India', 'Tropical', 'East India', 'Subtropical',
#        'Temperate', "['tropical', 'arid']", "['arid', 'subtropical']",
#        "['arid', 'temperate']", "['tropical']",
#        "['mountain', 'temperate']", "['humid']", "['subtropical']",
#        "['temperate']", "['tropical', 'temperate']", "['arid', 'humid']",
#        "['arid']", "['humid', 'subtropical']", "['mountain', 'tropical']",
#        "['temperate', 'subtropical']", "['temperate', 'mountain']",
#        "['subtropical', 'arid']", "['tropical', 'subtropical']",
#        "['temperate', 'tropical']", "['mountain', 'subtropical']",
#        "['humid', 'temperate']", "['mountain']", "['temperate', 'humid']",
#        "['humid', 'arid']", "['subtropical', 'mountain']",
#        "['tropical', 'mountain']", "['mountain', 'humid']",
#        "['mountain', 'arid']", "['subtropical', 'tropical']",
# ...
